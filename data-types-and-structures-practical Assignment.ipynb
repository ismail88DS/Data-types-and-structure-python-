# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Data Types and Structures Practical Assignment

# %%
# Write a code to create a string with your name and print it

name = "Mohammad Ismail Qazi"
print(name)
# Out:
# Mohammad Ismail Qazi

# %%
# Write a code to find the length of the string "Hello World"

text = "Hello World"
print(len(text))
# Out:
# 11

# %%
# Write a code to slice the first 3 characters from the string "Python Programming"

text = "Python Programming"
print(text[:3])
# Out:
# Pyt

# %%
# Write a code to convert the string "hello" to uppercase

text = "hello"
print(text.upper())
# Out:
# HELLO

# %%
# Write a code to replace the word "apple" with "orange" in the string "I like apple"

text = "I like apple"
print(text.replace("apple", "orange"))
# Out:
# I like orange

# %%
# Write a code to create a list with numbers 1 to 5 and print it

numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Write a code to append the number 10 to the list [1, 2, 3, 4]

numbers = [1, 2, 3, 4]
numbers.append(10)
print(numbers)
# Out:
# [1, 2, 3, 4, 10]

# %%
# Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]

numbers = [1, 2, 3, 4, 5]
numbers.remove(3)
print(numbers)
# Out:
# [1, 2, 4, 5]

# %%
# Write a code to access the second element in the list ['a', 'b', 'c', 'd']

letters = ['a', 'b', 'c', 'd']
print(letters[1])
# Out:
# b

# %%
# Write a code to reverse the list [10, 20, 30, 40, 50]

numbers = [10, 20, 30, 40, 50]
print(numbers[::-1])
# Out:
# [50, 40, 30, 20, 10]

# %%
# Create a tuple with elements 100, 200, 300 and print it

t = (100, 200, 300)
print(t)
# Out:
# (100, 200, 300)

# %%
# Access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')

colors = ('red', 'green', 'blue', 'yellow')
print(colors[-2])
# Out:
# blue

# %%
# Find the minimum number in the tuple (10, 20, 5, 15)

numbers = (10, 20, 5, 15)
print(min(numbers))
# Out:
# 5

# %%
# Find the index of "cat" in the tuple ('dog', 'cat', 'rabbit')

animals = ('dog', 'cat', 'rabbit')
print(animals.index('cat'))
# Out:
# 1

# %%
# Create a tuple with fruits and check if "kiwi" is in it

fruits = ('apple', 'banana', 'mango')
print('kiwi' in fruits)
# Out:
# False

# %%
# Create a set with elements 'a', 'b', 'c' and print it

s = {'a', 'b', 'c'}
print(s)
# Out:
# {'a', 'b', 'c'}

# %%
# Clear all elements from the set {1, 2, 3, 4, 5}

s = {1, 2, 3, 4, 5}
s.clear()
print(s)
# Out:
# set()

# %%
# Remove element 4 from the set {1, 2, 3, 4}

s = {1, 2, 3, 4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}

# %%
# Find the union of sets {1, 2, 3} and {3, 4, 5}

a = {1, 2, 3}
b = {3, 4, 5}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %%
# Find the intersection of sets {1, 2, 3} and {2, 3, 4}

a = {1, 2, 3}
b = {2, 3, 4}
print(a.intersection(b))
# Out:
# {2, 3}

# %%
# Create a dictionary with keys "name", "age", "city" and print it

person = {'name': 'Alice', 'age': 30, 'city': 'Paris'}
print(person)
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'Paris'}

# %%
# Add "country": "USA" to {'name': 'John', 'age': 25}

person = {'name': 'John', 'age': 25}
person['country'] = 'USA'
print(person)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
# Access value of key "name" in {'name': 'Alice', 'age': 30}

person = {'name': 'Alice', 'age': 30}
print(person['name'])
# Out:
# Alice

# %%
# Remove key "age" from {'name': 'Bob', 'age': 22, 'city': 'New York'}

person = {'name': 'Bob', 'age': 22, 'city': 'New York'}
del person['age']
print(person)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
# Check if key "city" exists in {'name': 'Alice', 'city': 'Paris'}

person = {'name': 'Alice', 'city': 'Paris'}
print('city' in person)
# Out:
# True

# %%
# Create a list, tuple, and dictionary, and print them

my_list = [1, 2, 3]
my_tuple = ('a', 'b', 'c')
my_dict = {'x': 10, 'y': 20}
print(my_list)
print(my_tuple)
print(my_dict)
# Out:
# [1, 2, 3]
# ('a', 'b', 'c')
# {'x': 10, 'y': 20}

# %%
# Create a list of 5 random numbers between 1 and 100, sort it

import random
numbers = random.sample(range(1, 101), 5)
numbers.sort()
print(numbers)
# Out:
# [13, 15, 22, 82, 89]

# %%
# Create a list with strings and print element at third index

words = ['apple', 'banana', 'cherry', 'date', 'fig']
print(words[3])
# Out:
# date

# %%
# Combine two dictionaries and print result

a = {'name': 'John'}
b = {'age': 25}
combined = {**a, **b}
print(combined)
# Out:
# {'name': 'John', 'age': 25}

# %%
# Convert a list of strings into a set

words = ['apple', 'banana', 'apple', 'cherry']
unique_words = set(words)
print(unique_words)
# Out:
# {'banana', 'apple', 'cherry'}
